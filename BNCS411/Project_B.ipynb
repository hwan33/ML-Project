# %%
#import packages
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import warnings, os
warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#load npy dataset
trn = np.load("/content/trn_dat.npy")
lbl = np.load("/content/trn_lbl.npy")
eval = np.load("/content/sample_evaluation_data.npy")

#check shape, ndim, dtype of dataset
print(trn.shape, lbl.shape, eval.shape)
print(trn.ndim, lbl.ndim, eval.ndim)
print(trn.dtype, lbl.dtype, eval.dtype)
# Out:
# (2800, 32, 32, 16) (2800,) (10, 32, 32, 16)
# 4 1 4
# float32 bool float32

# %%
#split dataset into train/validation/test set
from sklearn.model_selection import train_test_split

train, Test, train_lbl, Test_lbl = train_test_split(trn,lbl,test_size=0.1,random_state=44)

Train, Val, Train_lbl, Val_lbl = train_test_split(train, train_lbl, test_size=0.1, random_state=42)

#check shape of each set
print(Train.shape, Val.shape, Test.shape)
print(Train_lbl.shape, Val_lbl.shape, Test_lbl.shape)
# Out:
# (2268, 32, 32, 16) (252, 32, 32, 16) (280, 32, 32, 16)
# (2268,) (252,) (280,)

# %%
#reshape and normalize group for multi-layer perceptron model
Train_1 = Train.reshape(2268, 32*32*16).astype('float32') / 1000.0
Val_1 = Val.reshape(252, 32*32*16).astype('float32') / 1000.0
Test_1 = Test.reshape(280, 32*32*16).astype('float32') / 1000.0
eval_1 = eval.reshape(10, 32*32*16).astype('float32') / 1000.0

# %% [markdown]
# load and preprocessing
#
# I splited dataset into three part: Train set, Validation set, Test set.
# Then I checked shapes of each set to reshape and normalize data for multi-layer perceptron model.
#
# First, I reshaped 3d-array into 1d-array by multiplying value of height, width, and length.
# Dimentionality reduction made my model to perform faster and better.
#
# Second, I divided each nd-array by 1000.0 because every value of array is under 1000.
# By normalizing every value to 0~1, I minimized data duplication and my model could perform faster and better.

# %%
#import packages
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint

#make 1st model (multi-layer perceptron)
model1 = Sequential()
model1.add(Dense(256, input_dim=32*32*16, activation='relu'))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

# %%
#compile model
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#use checkpoint & early stopping for efficiency
model_dir = './model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path1 = model_dir + "/multilayer_perceptron.model"
    
checkpoint1 = ModelCheckpoint(filepath=model_path1, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping1 = EarlyStopping(monitor='val_loss', patience=7)

# %%
#fit model
hist1 = model1.fit(Train_1, Train_lbl, epochs=30, batch_size=32, 
                   validation_data=(Val_1, Val_lbl), callbacks=[checkpoint1, early_stopping1])
# Out:
# Epoch 1/30
# 71/71 [==============================] - ETA: 0s - loss: 1.0811 - accuracy: 0.5780
# Epoch 00001: val_loss improved from inf to 0.75991, saving model to ./model/multilayer_perceptron.model
# 71/71 [==============================] - 3s 41ms/step - loss: 1.0811 - accuracy: 0.5780 - val_loss: 0.7599 - val_accuracy: 0.5635
# Epoch 2/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.5668 - accuracy: 0.7098
# Epoch 00002: val_loss improved from 0.75991 to 0.54640, saving model to ./model/multilayer_perceptron.model
# 71/71 [==============================] - 3s 39ms/step - loss: 0.5670 - accuracy: 0.7099 - val_loss: 0.5464 - val_accuracy: 0.7183
# Epoch 3/30
# 71/71 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.7235
# Epoch 00003: val_loss did not improve from 0.54640
# 71/71 [==============================] - 2s 30ms/step - loss: 0.5559 - accuracy: 0.7235 - val_loss: 0.5821 - val_accuracy: 0.6825
# Epoch 4/30
# 71/71 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.7028
# Epoch 00004: val_loss did not improve from 0.54640
# 71/71 [==============================] - 2s 31ms/step - loss: 0.5816 - accuracy: 0.7028 - val_loss: 0.6555 - val_accuracy: 0.6310
# Epoch 5/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7579
# Epoch 00005: val_loss improved from 0.54640 to 0.53745, saving model to ./model/multilayer_perceptron.model
# 71/71 [==============================] - 3s 40ms/step - loss: 0.4932 - accuracy: 0.7579 - val_loss: 0.5375 - val_accuracy: 0.7460
# Epoch 6/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4652 - accuracy: 0.7773
# Epoch 00006: val_loss did not improve from 0.53745
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4652 - accuracy: 0.7773 - val_loss: 0.6149 - val_accuracy: 0.7302
# Epoch 7/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.7795
# Epoch 00007: val_loss did not improve from 0.53745
# 71/71 [==============================] - 2s 33ms/step - loss: 0.4711 - accuracy: 0.7795 - val_loss: 0.5847 - val_accuracy: 0.7143
# Epoch 8/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8091
# Epoch 00008: val_loss improved from 0.53745 to 0.49868, saving model to ./model/multilayer_perceptron.model
# 71/71 [==============================] - 3s 41ms/step - loss: 0.4223 - accuracy: 0.8091 - val_loss: 0.4987 - val_accuracy: 0.7540
# Epoch 9/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.8104
# Epoch 00009: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 32ms/step - loss: 0.4313 - accuracy: 0.8104 - val_loss: 0.8316 - val_accuracy: 0.5992
# Epoch 10/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8108
# Epoch 00010: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 31ms/step - loss: 0.4046 - accuracy: 0.8108 - val_loss: 0.6009 - val_accuracy: 0.7143
# Epoch 11/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8170
# Epoch 00011: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 31ms/step - loss: 0.4082 - accuracy: 0.8170 - val_loss: 0.5028 - val_accuracy: 0.7659
# Epoch 12/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8276
# Epoch 00012: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 32ms/step - loss: 0.3792 - accuracy: 0.8276 - val_loss: 0.5158 - val_accuracy: 0.7421
# Epoch 13/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8320
# Epoch 00013: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 30ms/step - loss: 0.3674 - accuracy: 0.8320 - val_loss: 0.6366 - val_accuracy: 0.7103
# Epoch 14/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3698 - accuracy: 0.8311
# Epoch 00014: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 30ms/step - loss: 0.3698 - accuracy: 0.8311 - val_loss: 0.7277 - val_accuracy: 0.6468
# Epoch 15/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8214
# Epoch 00015: val_loss did not improve from 0.49868
# 71/71 [==============================] - 2s 30ms/step - loss: 0.3909 - accuracy: 0.8214 - val_loss: 0.5648 - val_accuracy: 0.7341

# %%
#visualize loss, val_loss, acc, val_acc
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist1.history['loss'])
plt.plot(hist1.history['val_loss'])
plt.plot(hist1.history['accuracy'])
plt.plot(hist1.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.ylim([0.0, 1.2])
plt.show()

# %%
#express numerically
loss_and_metrics1 = model1.evaluate(Val_1, Val_lbl, batch_size=32)
print('## evaluation loss and_metrics ##')
print(loss_and_metrics1)
# Out:
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5648 - accuracy: 0.7341
# ## evaluation loss and_metrics ##
# [0.5647698640823364, 0.7341269850730896]

# %%
#function for evaluate model
def TF(x):
  for i in x:
    if i >= 0.5:
      print("True")
    else:
      print("False")

#evaluate
prediction1 = model1.predict(eval_1)

print(prediction1)
print(TF(prediction1))
# Out:
# [[0.02571476]
#  [0.11931819]
#  [0.0772185 ]
#  [0.6505257 ]
#  [0.25485855]
#  [0.02805167]
#  [0.00909016]
#  [0.04105526]
#  [0.00096974]
#  [0.07269681]]
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# None

# %%
#get accuracy score with test set
from sklearn.metrics import accuracy_score

test_prediction1 = model1.predict(Test_1)
test_prediction1 = np.round(test_prediction1)

accuracy1 = accuracy_score(Test_lbl, test_prediction1)
print("Accuracy: " + str(accuracy1))
# Out:
# Accuracy: 0.7321428571428571

# %% [markdown]
# Multi-layer perceptron
#
# I made model1 by adding several dense layers and I chose 'sigmoid' activation in last layer, not 'softmax' because I want binary classifying model.
# While compiling my model, I selected 'binary_crossentropy' and 'adam' parameter because they performs better for binary classification.
# I visualized model loss as a gragh and tested accuracy for test set.
#
# It scored 0.732.

# %%
#normalize group for CNN & deep CNN model
Train_2 = Train / 1000.0
Val_2 = Val / 1000.0
Test_2 = Test / 1000.0
eval_2 = eval / 1000.0

# %% [markdown]
# I only normalized train, validation, test, evaluation set because I think CNN and deep CNN model don't need reduced dimension.

# %%
#import packages
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Conv2D, MaxPooling2D, Flatten

#make 2nd model (CNN)
model2 = Sequential()
model2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 16)))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Conv2D(32, (3, 3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

# %%
#compile model
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#use checkpoint & early stopping for efficiency
model_dir = './model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path2 = model_dir + "/CNN.model"
    
checkpoint2 = ModelCheckpoint(filepath=model_path2, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping2 = EarlyStopping(monitor='val_loss', patience=7)

# %%
#fit model
hist2 = model2.fit(Train_2, Train_lbl, epochs=30, batch_size=32, 
                   validation_data=(Val_2, Val_lbl), callbacks=[checkpoint2, early_stopping2])
# Out:
# Epoch 1/30
# 71/71 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.7033
# Epoch 00001: val_loss improved from inf to 0.54674, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 59ms/step - loss: 0.5819 - accuracy: 0.7033 - val_loss: 0.5467 - val_accuracy: 0.7579
# Epoch 2/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.4555 - accuracy: 0.7924
# Epoch 00002: val_loss improved from 0.54674 to 0.48689, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 59ms/step - loss: 0.4559 - accuracy: 0.7923 - val_loss: 0.4869 - val_accuracy: 0.7698
# Epoch 3/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.3909 - accuracy: 0.8339
# Epoch 00003: val_loss improved from 0.48689 to 0.37923, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 62ms/step - loss: 0.3908 - accuracy: 0.8342 - val_loss: 0.3792 - val_accuracy: 0.8135
# Epoch 4/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3334 - accuracy: 0.8571
# Epoch 00004: val_loss improved from 0.37923 to 0.36702, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 60ms/step - loss: 0.3334 - accuracy: 0.8571 - val_loss: 0.3670 - val_accuracy: 0.8254
# Epoch 5/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.2886 - accuracy: 0.8830
# Epoch 00005: val_loss improved from 0.36702 to 0.33773, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2889 - accuracy: 0.8832 - val_loss: 0.3377 - val_accuracy: 0.8413
# Epoch 6/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.8875
# Epoch 00006: val_loss improved from 0.33773 to 0.32740, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 57ms/step - loss: 0.2628 - accuracy: 0.8876 - val_loss: 0.3274 - val_accuracy: 0.8452
# Epoch 7/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.2128 - accuracy: 0.9201
# Epoch 00007: val_loss improved from 0.32740 to 0.27936, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 58ms/step - loss: 0.2127 - accuracy: 0.9193 - val_loss: 0.2794 - val_accuracy: 0.8730
# Epoch 8/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.9402
# Epoch 00008: val_loss did not improve from 0.27936
# 71/71 [==============================] - 3s 48ms/step - loss: 0.1668 - accuracy: 0.9392 - val_loss: 0.2939 - val_accuracy: 0.8770
# Epoch 9/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.9433
# Epoch 00009: val_loss improved from 0.27936 to 0.27235, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 59ms/step - loss: 0.1639 - accuracy: 0.9440 - val_loss: 0.2723 - val_accuracy: 0.8968
# Epoch 10/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9590
# Epoch 00010: val_loss did not improve from 0.27235
# 71/71 [==============================] - 3s 48ms/step - loss: 0.1137 - accuracy: 0.9590 - val_loss: 0.4728 - val_accuracy: 0.8690
# Epoch 11/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1195 - accuracy: 0.9555
# Epoch 00011: val_loss did not improve from 0.27235
# 71/71 [==============================] - 3s 48ms/step - loss: 0.1195 - accuracy: 0.9555 - val_loss: 0.3617 - val_accuracy: 0.9048
# Epoch 12/30
# 71/71 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9727
# Epoch 00012: val_loss did not improve from 0.27235
# 71/71 [==============================] - 3s 48ms/step - loss: 0.0858 - accuracy: 0.9727 - val_loss: 0.3024 - val_accuracy: 0.9048
# Epoch 13/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9732
# Epoch 00013: val_loss did not improve from 0.27235
# 71/71 [==============================] - 3s 49ms/step - loss: 0.0716 - accuracy: 0.9731 - val_loss: 0.3579 - val_accuracy: 0.9008
# Epoch 14/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9750
# Epoch 00014: val_loss improved from 0.27235 to 0.24348, saving model to ./model/CNN.model
# 71/71 [==============================] - 4s 59ms/step - loss: 0.0695 - accuracy: 0.9744 - val_loss: 0.2435 - val_accuracy: 0.9246
# Epoch 15/30
# 71/71 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9797
# Epoch 00015: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 49ms/step - loss: 0.0530 - accuracy: 0.9797 - val_loss: 0.3536 - val_accuracy: 0.8889
# Epoch 16/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9835
# Epoch 00016: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 49ms/step - loss: 0.0537 - accuracy: 0.9837 - val_loss: 0.3029 - val_accuracy: 0.9286
# Epoch 17/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0553 - accuracy: 0.9808
# Epoch 00017: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 49ms/step - loss: 0.0554 - accuracy: 0.9810 - val_loss: 0.3802 - val_accuracy: 0.8690
# Epoch 18/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9821
# Epoch 00018: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 49ms/step - loss: 0.0513 - accuracy: 0.9824 - val_loss: 0.2782 - val_accuracy: 0.9365
# Epoch 19/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9964
# Epoch 00019: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 48ms/step - loss: 0.0207 - accuracy: 0.9965 - val_loss: 0.2802 - val_accuracy: 0.9206
# Epoch 20/30
# 70/71 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9951
# Epoch 00020: val_loss did not improve from 0.24348
# 71/71 [==============================] - 3s 48ms/step - loss: 0.0187 - accuracy: 0.9951 - val_loss: 0.3256 - val_accuracy: 0.8929
# Epoch 21/30
# 71/71 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9982
# Epoch 00021: val_loss did not improve from 0.24348
# 71/71 [==============================] - 4s 50ms/step - loss: 0.0103 - accuracy: 0.9982 - val_loss: 0.3479 - val_accuracy: 0.9246

# %%
#visualize loss, val_loss, acc, val_acc
plt.plot(hist2.history['loss'])
plt.plot(hist2.history['val_loss'])
plt.plot(hist2.history['accuracy'])
plt.plot(hist2.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.ylim([0.0, 1.2])
plt.show()

# %%
#express numerically
loss_and_metrics2 = model2.evaluate(Val_2, Val_lbl, batch_size=32)
print('## evaluation loss and_metrics ##')
print(loss_and_metrics2)
# Out:
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3479 - accuracy: 0.9246
# ## evaluation loss and_metrics ##
# [0.34786614775657654, 0.9246031641960144]

# %%
#evaluate
prediction2 = model2.predict(eval_2)

print(prediction2)
print(TF(prediction2))
# Out:
# [[2.16037035e-04]
#  [3.11774015e-03]
#  [1.13505125e-02]
#  [3.01247674e-05]
#  [1.66302919e-03]
#  [2.38594876e-05]
#  [8.81642103e-04]
#  [4.59765673e-01]
#  [1.75299522e-06]
#  [5.28085828e-02]]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# None

# %%
#get accuracy score with test set
test_prediction2 = model2.predict(Test_2)
test_prediction2 = np.round(test_prediction2)

accuracy2 = accuracy_score(Test_lbl, test_prediction2)
print("Accuracy: " + str(accuracy2))
# Out:
# Accuracy: 0.8714285714285714

# %% [markdown]
# CNN
#
# I made model2 by adding several Conv2D, MaxPooling2D, Flatten, and Dense layers  and I chose 'sigmoid' activation in last layer, not 'softmax' because I want binary classifying model.
# While compiling my model, I selected 'binary_crossentropy' and 'adam' parameter because they performs better for binary classification.
# I visualized model loss as a gragh and tested accuracy for test set.
#
# It scored 0.871.

# %%
from keras.layers import Dropout

#make 3rd model (deep CNN)
model3 = Sequential()
model3.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32,32,16)))
model3.add(Conv2D(32, (3, 3), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.25))
model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(Conv2D(64, (3, 3), activation='relu'))
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.25))
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))
model3.add(Dense(1, activation='sigmoid'))

# %%
#compile model
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#use checkpoint & early stopping for efficiency
model_dir = './model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path3 = model_dir + "/deep CNN.model"
    
checkpoint3 = ModelCheckpoint(filepath=model_path3, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping3 = EarlyStopping(monitor='val_loss', patience=7)

# %%
#fit model
hist3 = model3.fit(Train_2, Train_lbl, epochs=30, batch_size=32, 
                   validation_data=(Val_2, Val_lbl), callbacks=[checkpoint3, early_stopping3])
# Out:
# Epoch 1/30
# 71/71 [==============================] - ETA: 0s - loss: 0.6409 - accuracy: 0.6552
# Epoch 00001: val_loss improved from inf to 0.59366, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 144ms/step - loss: 0.6409 - accuracy: 0.6552 - val_loss: 0.5937 - val_accuracy: 0.6706
# Epoch 2/30
# 71/71 [==============================] - ETA: 0s - loss: 0.5442 - accuracy: 0.7584
# Epoch 00002: val_loss improved from 0.59366 to 0.50678, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 141ms/step - loss: 0.5442 - accuracy: 0.7584 - val_loss: 0.5068 - val_accuracy: 0.7778
# Epoch 3/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.7866
# Epoch 00003: val_loss did not improve from 0.50678
# 71/71 [==============================] - 9s 124ms/step - loss: 0.4787 - accuracy: 0.7866 - val_loss: 0.5396 - val_accuracy: 0.7341
# Epoch 4/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.8016
# Epoch 00004: val_loss improved from 0.50678 to 0.43923, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 143ms/step - loss: 0.4480 - accuracy: 0.8016 - val_loss: 0.4392 - val_accuracy: 0.8016
# Epoch 5/30
# 71/71 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.8250
# Epoch 00005: val_loss improved from 0.43923 to 0.37872, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 11s 153ms/step - loss: 0.4119 - accuracy: 0.8250 - val_loss: 0.3787 - val_accuracy: 0.8214
# Epoch 6/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8514
# Epoch 00006: val_loss improved from 0.37872 to 0.28218, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 12s 168ms/step - loss: 0.3549 - accuracy: 0.8514 - val_loss: 0.2822 - val_accuracy: 0.8690
# Epoch 7/30
# 71/71 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8708
# Epoch 00007: val_loss improved from 0.28218 to 0.28079, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 11s 154ms/step - loss: 0.3207 - accuracy: 0.8708 - val_loss: 0.2808 - val_accuracy: 0.8770
# Epoch 8/30
# 71/71 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8823
# Epoch 00008: val_loss improved from 0.28079 to 0.27610, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 145ms/step - loss: 0.2921 - accuracy: 0.8823 - val_loss: 0.2761 - val_accuracy: 0.8690
# Epoch 9/30
# 71/71 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9043
# Epoch 00009: val_loss improved from 0.27610 to 0.20116, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 11s 150ms/step - loss: 0.2423 - accuracy: 0.9043 - val_loss: 0.2012 - val_accuracy: 0.9087
# Epoch 10/30
# 71/71 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9052
# Epoch 00010: val_loss did not improve from 0.20116
# 71/71 [==============================] - 9s 125ms/step - loss: 0.2323 - accuracy: 0.9052 - val_loss: 0.2580 - val_accuracy: 0.8810
# Epoch 11/30
# 71/71 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9136
# Epoch 00011: val_loss did not improve from 0.20116
# 71/71 [==============================] - 9s 125ms/step - loss: 0.2263 - accuracy: 0.9136 - val_loss: 0.2030 - val_accuracy: 0.9127
# Epoch 12/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9295
# Epoch 00012: val_loss improved from 0.20116 to 0.17998, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 145ms/step - loss: 0.1723 - accuracy: 0.9295 - val_loss: 0.1800 - val_accuracy: 0.9167
# Epoch 13/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9330
# Epoch 00013: val_loss did not improve from 0.17998
# 71/71 [==============================] - 9s 124ms/step - loss: 0.1776 - accuracy: 0.9330 - val_loss: 0.2442 - val_accuracy: 0.9087
# Epoch 14/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9409
# Epoch 00014: val_loss improved from 0.17998 to 0.15903, saving model to ./model/deep CNN.model
# 71/71 [==============================] - 10s 143ms/step - loss: 0.1600 - accuracy: 0.9409 - val_loss: 0.1590 - val_accuracy: 0.9365
# Epoch 15/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9489
# Epoch 00015: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 125ms/step - loss: 0.1382 - accuracy: 0.9489 - val_loss: 0.1784 - val_accuracy: 0.9365
# Epoch 16/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9330
# Epoch 00016: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 125ms/step - loss: 0.1531 - accuracy: 0.9330 - val_loss: 0.1952 - val_accuracy: 0.9563
# Epoch 17/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9440
# Epoch 00017: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 124ms/step - loss: 0.1459 - accuracy: 0.9440 - val_loss: 0.1708 - val_accuracy: 0.9365
# Epoch 18/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.9528
# Epoch 00018: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 125ms/step - loss: 0.1223 - accuracy: 0.9528 - val_loss: 0.1724 - val_accuracy: 0.9524
# Epoch 19/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9480
# Epoch 00019: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 125ms/step - loss: 0.1218 - accuracy: 0.9480 - val_loss: 0.1631 - val_accuracy: 0.9365
# Epoch 20/30
# 71/71 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9546
# Epoch 00020: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 124ms/step - loss: 0.1166 - accuracy: 0.9546 - val_loss: 0.1759 - val_accuracy: 0.9405
# Epoch 21/30
# 71/71 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9709
# Epoch 00021: val_loss did not improve from 0.15903
# 71/71 [==============================] - 9s 124ms/step - loss: 0.0734 - accuracy: 0.9709 - val_loss: 0.1947 - val_accuracy: 0.9325

# %%
#visualize loss, val_loss, acc, val_acc
plt.plot(hist3.history['loss'])
plt.plot(hist3.history['val_loss'])
plt.plot(hist3.history['accuracy'])
plt.plot(hist3.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.ylim([0.0, 1.2])
plt.show()

# %%
#express numerically
loss_and_metrics3 = model3.evaluate(Val_2, Val_lbl, batch_size=32)
print('## evaluation loss and_metrics ##')
print(loss_and_metrics3)
# Out:
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1947 - accuracy: 0.9325
# ## evaluation loss and_metrics ##
# [0.19465745985507965, 0.932539701461792]

# %%
#evaluate
prediction3 = model3.predict(eval_2)

print(prediction3)
print(TF(prediction3))
# Out:
# [[4.6847463e-03]
#  [4.3731928e-04]
#  [1.1657488e-01]
#  [6.1817755e-06]
#  [4.2209029e-04]
#  [1.0415018e-03]
#  [1.0945618e-02]
#  [1.9572526e-02]
#  [1.6920835e-02]
#  [6.0739040e-02]]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# None

# %%
#get accuracy score with test set
test_prediction3 = model3.predict(Test_2)
test_prediction3 = np.round(test_prediction3)

accuracy3 = accuracy_score(Test_lbl, test_prediction3)
print("Accuracy: " + str(accuracy3))
# Out:
# Accuracy: 0.9142857142857143

# %% [markdown]
# deep CNN
#
# I made model3 by adding more Conv2D, MaxPooling2D, Flatten, and Dense layers and I chose 'sigmoid' activation in last layer, not 'softmax' because I want binary classifying model.
# I also used dropout layer to avoid model to be overfitted.
# While compiling my model, I selected 'binary_crossentropy' and 'adam' parameter because they performs better for binary classification.
# I visualized model loss as a gragh and tested accuracy for test set.
#
# It scored 0.914

# %% [markdown]
# The limitation of multilayer perceptron is that it lacks the ability to learn and predict images. It is an inefficient problem to perform operations on the same image each time even if the position of objects in the image varies slightly. By recognizing as a completely different input as the location changes, I think multilayer perceptron cannot perform better than CNN model.
#
# However, CNN is a powerful algorithm for image recognition. Convolution process happens while data pass between input and hidden layer. It is much more sparsed layer than fully connected layer. In addition, Pooling process makes dimension shrinkage one more time. The reduced dimension results low computation, translation invariance, transformation invariance. By these newly added layers make great performance of CNN model in image process.

# %%
#save model architecture
model_json = model3.to_json()
with open("model.json", "w") as json_file : 
    json_file.write(model_json)

# %%
#save model weights
model3.save_weights("model.h5")

# %%
#summary of best model
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 479,425
# Trainable params: 479,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
#plot best model
tf.keras.utils.plot_model(
    model3, to_file='model3.png', show_shapes=True, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)

# %% [markdown]
# I chose model3 (deep CNN model) to my best model.
#
# Then I searched for summary and plot of my best model.
# I have noticed that only Conv2D and Dense layers are increasing the depth(# param) of the model. It increased to 409856 in dense_6 layer and decreased to 257 in last dense layer.
#
# After looking at the plot of my model, I could understand about the role of each layers and the change of input & output shape vector easily.
